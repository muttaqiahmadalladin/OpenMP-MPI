# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
#OPENMP CASE

# %%
'''omp_1_static=[# ignore this as it is using 1thread static
    0.166334,
0.166272,
0.166209,
0.168736,
0.168982,
0.16705,
0.169292,
0.168469,
0.16859,
0.155839,

]'''
# Out:
# 'omp_1_static=[\n    0.166334,\n0.166272,\n0.166209,\n0.168736,\n0.168982,\n0.16705,\n0.169292,\n0.168469,\n0.16859,\n0.155839,\n\n]'

# %%
'''mean_1tstatic=sum(omp_1_static)/len(omp_1_static)
mean_1tstatic'''
# Out:
# 'mean_1tstatic=sum(omp_1_static)/len(omp_1_static)\nmean_1tstatic'

# %%
omp_1_static=[
   0.161305,
0.162573,
0.161906,
0.163817,
0.162621,
0.164072,
0.162861,
0.161702,
0.163119,
0.162535,

]

# %%
mean_1tstatic=sum(omp_1_static)/len(omp_1_static)
mean_1tstatic
# Out:
# 0.1626511

# %%
omp_2_static=[
    0.122143,
0.11166,
0.111934,
0.115973,
0.107722,
0.114651,
0.114728,
0.117687,
0.10943,
0.121506,

]

# %%
mean_2static=sum(omp_2_static)/len(omp_2_static)
mean_2static
# Out:
# 0.11474340000000001

# %%
omp_4_static=[
    0.056385,
0.0505615,
0.0505394,
0.0480742,
0.0460362,
0.0471504,
0.0476071,
0.044509,
0.0473687,
0.0466824,

]

# %%
mean_4static=sum(omp_4_static)/len(omp_4_static)
mean_4static
# Out:
# 0.04849139

# %%
omp_8_static=[
    0.0387208,
0.0464555,
0.0417397,
0.031519,
0.0485641,
0.0340741,
0.0418834,
0.0353986,
0.0700856,
0.0315275,

    
]

# %%
mean_8static=sum(omp_8_static)/len(omp_8_static)
mean_8static
# Out:
# 0.04199683

# %%
omp_16_static=[
    0.134312,
0.152184,
0.148096,
0.14992,
0.136438,
0.152864,
0.145588,
0.140065,
0.145543,
0.147147,

]

# %%
mean_16static=sum(omp_16_static)/len(omp_16_static)
mean_16static
# Out:
# 0.14521569999999998

# %%
omp_32_static=[
    0.260556,
0.273162,
0.249569,
0.265561,
0.248866,
0.241428,
0.25023,
0.249921,
0.25222,
0.263983,

]

# %%
mean_32static=sum(omp_32_static)/len(omp_32_static)
mean_32static
# Out:
# 0.2555496

# %%
threads=[1,2,4,8,16,32]

# %%
values =[mean_1tstatic,mean_2static,mean_4static,mean_8static,mean_16static,mean_32static]

# %%
values
# Out:
# [0.1626511,
#  0.11474340000000001,
#  0.04849139,
#  0.04199683,
#  0.14521569999999998,
#  0.2555496]

# %%
speedups=[1,2,3,4,5,6]#flagvalues
for i in range(6):
    speedups[i]=mean_1tstatic/values[i]

# %%
speedups
# Out:
# [1.0,
#  1.4175203105363792,
#  3.3542263894683155,
#  3.8729375526676657,
#  1.1200655301045275,
#  0.6364756587370906]

# %%
df=pd.DataFrame(threads)

# %%
df["speedup"]=pd.DataFrame(speedups)

# %%
df
# Out:
#     0   speedup
# 0   1  1.000000
# 1   2  1.417520
# 2   4  3.354226
# 3   8  3.872938
# 4  16  1.120066
# 5  32  0.636476

# %%
df.set_index(0)
# Out:
#      speedup
# 0
# 1   1.000000
# 2   1.417520
# 4   3.354226
# 8   3.872938
# 16  1.120066
# 32  0.636476

# %%
# %matplotlib notebook
ax=df.plot(y='speedup',x=0,use_index=True,)
ax.set_xlabel('# of Threads', alpha = 0.8)
ax.set_ylabel('Speed Up' , alpha = 0.8)
for spine in ax.spines:
    ax.spines[spine].set_visible(False)
    ax.tick_params(axis=u'both', which=u'both',length=0)
plt.savefig('lineplot_speedup_static.png')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
ThreadList=["1 T","2 T","4 T","8 T","16 T","32 T"]
df["threads"]=pd.DataFrame(["1 T","2 T","4 T","8 T","16 T","32 T"])
df.set_index('threads')
# Out:
#           0   speedup
# threads
# 1 T       1  1.000000
# 2 T       2  1.417520
# 4 T       4  3.354226
# 8 T       8  3.872938
# 16 T     16  1.120066
# 32 T     32  0.636476

# %%
# %matplotlib notebook
ax=df.plot(y='speedup',x='threads',kind='bar')
ax.set_xlabel('# of Threads', alpha = 0.8)
ax.set_ylabel('Speed Up' , alpha = 0.8)
for spine in ax.spines:
    ax.spines[spine].set_visible(False)
    ax.tick_params(axis=u'both', which=u'both',length=0)
plt.savefig('Barplot_speedup_static.png')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
df
# Out:
#     0   speedup threads
# 0   1  1.000000     1 T
# 1   2  1.417520     2 T
# 2   4  3.354226     4 T
# 3   8  3.872938     8 T
# 4  16  1.120066    16 T
# 5  32  0.636476    32 T

# %%
print(df[0],df['speedup'])
# Out:
# 0     1
# 1     2
# 2     4
# 3     8
# 4    16
# 5    32
# Name: 0, dtype: int64 0    1.000000
# 1    1.417520
# 2    3.354226
# 3    3.872938
# 4    1.120066
# 5    0.636476
# Name: speedup, dtype: float64

# %%
'''part 2 try once more'''
# Out:
# 'part 2 try once more'

# %%
threads=[2,4,8,16,32]

# %%
values =[mean_2static,mean_4static,mean_8static,mean_16static,mean_32static]

# %%
values
# Out:
# [0.11474340000000001, 0.04849139, 0.04199683, 0.14521569999999998, 0.2555496]

# %%
speedups=[1,2,3,4,5]#flagvalues
for i in range(5):
    speedups[i]=mean_1tstatic/values[i]

# %%
speedups
# Out:
# [1.4175203105363792,
#  3.3542263894683155,
#  3.8729375526676657,
#  1.1200655301045275,
#  0.6364756587370906]

# %%
df=pd.DataFrame(threads)

# %%
df["speedup"]=pd.DataFrame(speedups)

# %%
df
# Out:
#     0   speedup
# 0   2  1.417520
# 1   4  3.354226
# 2   8  3.872938
# 3  16  1.120066
# 4  32  0.636476

# %%
df.set_index(0)
# Out:
#      speedup
# 0
# 2   1.417520
# 4   3.354226
# 8   3.872938
# 16  1.120066
# 32  0.636476

# %%
# %matplotlib notebook
ax=df.plot(y='speedup',x=0,use_index=True,)
ax.set_xlabel('# of Threads', alpha = 0.8)
ax.set_ylabel('Speed Up' , alpha = 0.8)
for spine in ax.spines:
    ax.spines[spine].set_visible(False)
    ax.tick_params(axis=u'both', which=u'both',length=0)
plt.savefig('lineplot_speedup_static_without1.png')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
ThreadList=["2 T","4 T","8 T","16 T","32 T"]
df["threads"]=pd.DataFrame(["2 T","4 T","8 T","16 T","32 T"])
df.set_index('threads')
# Out:
#           0   speedup
# threads
# 2 T       2  1.417520
# 4 T       4  3.354226
# 8 T       8  3.872938
# 16 T     16  1.120066
# 32 T     32  0.636476

# %%
# %matplotlib notebook
ax=df.plot(y='speedup',x='threads',kind='bar')
ax.set_xlabel('# of Threads', alpha = 0.8)
ax.set_ylabel('Speed Up' , alpha = 0.8)
for spine in ax.spines:
    ax.spines[spine].set_visible(False)
    ax.tick_params(axis=u'both', which=u'both',length=0)
plt.savefig('Barplot_speedup_static_without_1tst.png')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
'''DYNAMIC CASE'''
# Out:
# 'DYNAMIC CASE'

# %%
omp_2_dynamic=[
    1.33465,
1.3116,
1.28554,
1.28954,
1.22316,
1.14572,
1.21935,
1.19379,
1.23482,
1.28209,

]

# %%
mean_2dynamic=sum(omp_2_dynamic)/len(omp_2_dynamic)
mean_2dynamic
# Out:
# 1.252026

# %%
omp_4_dynamic=[
    1.75425,
1.82273,
1.70508,
1.79929,
1.75018,
1.85969,
1.73333,
1.70742,
1.79199,
1.66841,

]

# %%
mean_4dynamic=sum(omp_4_dynamic)/len(omp_4_dynamic)
mean_4dynamic
# Out:
# 1.759237

# %%
omp_8_dynamic=[
    1.97088,
1.71536,
1.65543,
1.71482,
1.73453,
1.7017,
1.8178,
1.94309,
1.94098,
1.917,

]

# %%
mean_8dynamic=sum(omp_8_dynamic)/len(omp_8_dynamic)
mean_8dynamic
# Out:
# 1.8111590000000004

# %%
omp_16_dynamic=[
    1.779987,
1.94294,
1.90832,
2.06697,
2.02656,
2.02389,
1.96821,
2.1087,
2.11159,
2.02128,

]

# %%
mean_16dynamic=sum(omp_16_dynamic)/len(omp_16_dynamic)
mean_16dynamic
# Out:
# 1.9958447

# %%
omp_32_dynamic=[
2.14421,
2.16596,
2.17596,
2.01175,
2.02446,
2.11971,
2.03874,
2.11786,
2.01813,
2.03861,

]

# %%
mean_32dynamic=sum(omp_32_dynamic)/len(omp_32_dynamic)
mean_32dynamic
# Out:
# 2.085539

# %%
threads=[2,4,8,16,32]
valuesd =[mean_2dynamic,mean_4dynamic,mean_8dynamic,mean_16dynamic,mean_32dynamic]
speedupsd=[1,2,3,4,5]#flagvalues
for i in range(5):
    speedupsd[i]=mean_1tstatic/valuesd[i]

# %%
valuesd
# Out:
# [1.252026, 1.759237, 1.8111590000000004, 1.9958447, 2.085539]

# %%
speedupsd
# Out:
# [0.12991032135115405,
#  0.09245547927880098,
#  0.08980498123025088,
#  0.08149486781210984,
#  0.07798995847116741]

# %%
dfd=pd.DataFrame(threads)
dfd["speedup"]=pd.DataFrame(speedupsd)

dfd
# Out:
#     0   speedup
# 0   2  0.129910
# 1   4  0.092455
# 2   8  0.089805
# 3  16  0.081495
# 4  32  0.077990

# %%
dfd.set_index(0)
# Out:
#      speedup
# 0
# 2   0.129910
# 4   0.092455
# 8   0.089805
# 16  0.081495
# 32  0.077990

# %%
# %matplotlib notebook
ax=dfd.plot(y='speedup',x=0,use_index=True,)
ax.set_xlabel('# of Threads', alpha = 0.8)
ax.set_ylabel('Speed Up' , alpha = 0.8)
for spine in ax.spines:
    ax.spines[spine].set_visible(False)
    ax.tick_params(axis=u'both', which=u'both',length=0)
plt.savefig('lineplot_speedup_dynamic_without1.png')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
ThreadList=["2 T","4 T","8 T","16 T","32 T"]
dfd["threads"]=pd.DataFrame(["2 T","4 T","8 T","16 T","32 T"])
dfd.set_index('threads')
# Out:
#           0   speedup
# threads
# 2 T       2  0.129910
# 4 T       4  0.092455
# 8 T       8  0.089805
# 16 T     16  0.081495
# 32 T     32  0.077990

# %%
# %matplotlib notebook
ax=dfd.plot(y='speedup',x='threads',kind='bar')
ax.set_xlabel('# of Threads', alpha = 0.8)
ax.set_ylabel('Speed Up' , alpha = 0.8)
for spine in ax.spines:
    ax.spines[spine].set_visible(False)
    ax.tick_params(axis=u'both', which=u'both',length=0)
plt.savefig('Barplot_speedup_dynamic_without_1tst.png')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
'''Q2 MPI'''
# Out:
# 'Q2 MPI'

# %%
mpi_1t=[
0.027499,
0.187619,
0.099823,
0.186348,
0.190305,
0.189825,
0.189206,
0.189511,
0.189740,
0.167472,
0.186152,
0.186227,
0.186623,
0.169931,
0.184345,
0.185687,
0.186579,
0.186338,
0.193494,
0.186325,
0.189772,
0.175033,
0.183467,
0.165575,
0.005022,
0.127482,
0.192176,
0.186860,
0.187405,
0.187058,
0.189200,
0.192264,
0.005081,
0.184976,
0.185869,
0.189237,
0.191303,
0.191595,
0.057455,
0.154387,
0.184600,
0.190787,
0.182114,
0.186986,
0.182968,
0.191390,
0.185766,
0.187304,
0.046901,
0.189165,

]
len(mpi_1t)
# Out:
# 50

# %%
mpi_1tmean=sum(mpi_1t)/len(mpi_1t)
mpi_1tmean
# Out:
# 0.16676494000000003

# %%
mpi_2t=[
0.028818,
0.135448,
0.085514,
0.132125,
0.112843,
0.110086,
0.083744,
0.118911,
0.105722,
0.109066,
0.128057,
0.106135,
0.133784,
0.129672,
0.133380,
0.128728,
0.125855,
0.112666,
0.112996,
0.105006,
0.143037,
0.113130,
0.112571,
0.111596,
0.004703,
0.140665,
0.123463,
0.137912,
0.107940,
0.106952,
0.108095,
0.105926,
0.006084,
0.093727,
0.109792,
0.108423,
0.130903,
0.114810,
0.059937,
0.105439,
0.111373,
0.085859,
0.111830,
0.109994,
0.112676,
0.086113,
0.140357,
0.141691,
0.051387,
0.108470,

]
len(mpi_2t)
# Out:
# 50

# %%
mpi_2tmean=sum(mpi_2t)/len(mpi_2t)
mpi_2tmean
# Out:
# 0.10686822000000003

# %%
mpi_4t=[
0.029183,
0.062134,
0.064701,
0.043061,
0.043245,
0.066866,
0.061065,
0.050018,
0.043332,
0.062932,
0.046007,
0.059987,
0.064740,
0.055490,
0.056710,
0.048777,
0.062603,
0.059135,
0.050509,
0.063573,
0.064145,
0.049899,
0.061787,
0.059474,
0.062773,
0.060246,
0.066041,
0.045375,
0.043226,
0.063893,
0.057607,
0.046793,
0.006296,
0.042788,
0.061536,
0.043042,
0.070112,
0.068810,
0.042502,
0.051107,
0.060936,
0.064896,
0.043432,
0.043007,
0.060279,
0.071746,
0.044970,
0.051152,
0.037139,
0.042938,

]
len(mpi_4t)
# Out:
# 50

# %%
mpi_4tmean=sum(mpi_4t)/len(mpi_4t)
mpi_4tmean
# Out:
# 0.053640299999999995

# %%
mpi_8t=[
0.026773,
0.027788,
0.022299,
0.024772,
0.033978,
0.022285,
0.022429,
0.022947,
0.022325,
0.022474,
0.022282,
0.022404,
0.022585,
0.023013,
0.023510,
0.022709,
0.022430,
0.035752,
0.022401,
0.021448,
0.032363,
0.022696,
0.022417,
0.024774,
0.024513,
0.022353,
0.022326,
0.038423,
0.026625,
0.022372,
0.023289,
0.022729,
0.022737,
0.027069,
0.038902,
0.023726,
0.022305,
0.026625,
0.023819,
0.022858,
0.022946,
0.022402,
0.022445,
0.022453,
0.023258,
0.022847,
0.022385,
0.022965,
0.022394,
0.022542,

]
len(mpi_8t)
# Out:
# 50

# %%
mpi_8tmean=sum(mpi_8t)/len(mpi_8t)
mpi_8tmean
# Out:
# 0.02452324000000001

# %%
mpi_16t=[
0.012717,
0.012620,
0.012839,
0.011204,
0.011634,
0.011568,
0.011589,
0.011423,
0.011313,
0.011485,
0.011137,
0.011762,
0.011369,
0.011145,
0.011587,
0.011652,
0.011595,
0.011455,
0.011577,
0.011385,
0.011430,
0.011113,
0.011341,
0.011490,
0.003478,
0.011241,
0.011307,
0.011531,
0.011288,
0.011225,
0.011597,
0.011653,
0.003404,
0.011481,
0.012706,
0.011305,
0.011471,
0.011451,
0.011623,
0.024416,
0.011434,
0.011375,
0.027851,
0.011536,
0.011230,
0.011909,
0.011334,
0.011301,
0.006994,
0.012023,

]
len(mpi_16t)
# Out:
# 50

# %%
mpi_16tmean=sum(mpi_16t)/len(mpi_16t)
mpi_16tmean
# Out:
# 0.011731879999999998

# %%
mpi_32t=[
0.008262,
0.007981,
0.025752,
0.007609,
0.007361,
0.031605,
0.023141,
0.007633,
0.017145,
0.007657,
0.007547,
0.016695,
0.017402,
0.007463,
0.007625,
0.007312,
0.007552,
0.023602,
0.007686,
0.007653,
0.007473,
0.023506,
0.009021,
0.007673,
0.004586,
0.007369,
0.007882,
0.007621,
0.007608,
0.007342,
0.006732,
0.020358,
0.004502,
0.007456,
0.007689,
0.000982,
0.001770,
0.007556,
0.002903,
0.007639,
0.007480,
0.001520,
0.001515,
0.007541,
0.007474,
0.007405,
0.007670,
0.007428,
0.000303,
0.007071,

]
len(mpi_32t)
# Out:
# 50

# %%
mpi_32tmean=sum(mpi_32t)/len(mpi_32t)
mpi_32tmean
# Out:
# 0.00935516

# %%
mpi_64t=[
0.005511,
0.005282,
0.005082,
0.005063,
0.030224,
0.040095,
0.005115,
0.005393,
0.009182,
0.005130,
0.005050,
0.041926,
0.004936,
0.002805,
0.004925,
0.005243,
0.033146,
0.045137,
0.005142,
0.005116,
0.005145,
0.004908,
0.001199,
0.005126,
0.001385,
0.005105,
0.005147,
0.005306,
0.035698,
0.005190,
0.009245,
0.002963,
0.005026,
0.001235,
0.005179,
0.001038,
0.004151,
0.005015,
0.002112,
0.007134,
0.009084,
0.005095,
0.008691,
0.005140,
0.005185,
0.005090,
0.004967,
0.002549,
0.001236,
0.005249,

]
len(mpi_64t)
# Out:
# 50

# %%
mpi_64tmean=sum(mpi_64t)/len(mpi_64t)
mpi_64tmean
# Out:
# 0.00878192

# %%
threads_mpi=[2,4,8,16,32,64]
values_mpi =[mpi_2tmean,mpi_4tmean,mpi_8tmean,mpi_16tmean,mpi_32tmean,mpi_64tmean]
speedups_mpi=[1,2,3,4,5,6]#flagvalues
for i in range(6):
    speedups_mpi[i]=mpi_1tmean/values_mpi[i]
speedups_mpi
# Out:
# [1.560472701800404,
#  3.108948682240779,
#  6.80028169197871,
#  14.214681704892996,
#  17.82598480410811,
#  18.989576311330556]

# %%
values_mpi
# Out:
# [0.10686822000000003,
#  0.053640299999999995,
#  0.02452324000000001,
#  0.011731879999999998,
#  0.00935516,
#  0.00878192]

# %%
df_mpi=pd.DataFrame(threads_mpi)
df_mpi["speedup"]=pd.DataFrame(speedups_mpi)

df_mpi
# Out:
#     0    speedup
# 0   2   1.560473
# 1   4   3.108949
# 2   8   6.800282
# 3  16  14.214682
# 4  32  17.825985
# 5  64  18.989576

# %%
df_mpi.set_index(0)
# Out:
#       speedup
# 0
# 2    1.560473
# 4    3.108949
# 8    6.800282
# 16  14.214682
# 32  17.825985
# 64  18.989576

# %%
df_mpi
# Out:
#     0    speedup
# 0   2   1.560473
# 1   4   3.108949
# 2   8   6.800282
# 3  16  14.214682
# 4  32  17.825985
# 5  64  18.989576

# %%
# %matplotlib notebook
ax=df_mpi.plot(y='speedup',x=0,use_index=True,)
ax.set_xlabel('# of Threads', alpha = 0.8)
ax.set_ylabel('Speed Up' , alpha = 0.8)
for spine in ax.spines:
    ax.spines[spine].set_visible(False)
    ax.tick_params(axis=u'both', which=u'both',length=0)
plt.savefig('lineplot_speedup_MPI.png')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
ThreadList_mpi=["2 T","4 T","8 T","16 T","32 T","64"]
df_mpi["threads"]=pd.DataFrame(["2 T","4 T","8 T","16 T","32 T","64 T"])
df_mpi.set_index('threads')
# Out:
#           0    speedup
# threads
# 2 T       2   1.560473
# 4 T       4   3.108949
# 8 T       8   6.800282
# 16 T     16  14.214682
# 32 T     32  17.825985
# 64 T     64  18.989576

# %%
# %matplotlib notebook
ax=df_mpi.plot(y='speedup',x='threads',kind='bar')
ax.set_xlabel('# of Threads', alpha = 0.8)
ax.set_ylabel('Speed Up' , alpha = 0.8)
for spine in ax.spines:
    ax.spines[spine].set_visible(False)
    ax.tick_params(axis=u'both', which=u'both',length=0)
plt.savefig('Barplot_speedup_MPI.png')
# Out:
# <img src="data:image/png;base64,..." width="640">
